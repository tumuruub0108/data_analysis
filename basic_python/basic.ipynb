# %% [markdown]
# Here re is the module containing functions and constants for working with regular
# expressions.

# %%
import re

# %%
my_regex = re.compile("[0-9]+", re.I)

# %% [markdown]
# # Function
# A function is a rule for taking zero or more inputs and returning a corrresponding output. Python functions are first-class, which means that we can assign them to variables
# and pass them into functions just like any other arguments:

# %%
def double(x):
    return x * 2

# %%
def apply_to_one(f):
    return f(1)

my_double = double
x = apply_to_one(my_double)
x
# Out:
# 2

# %% [markdown]
# It is also easy to create short anonymous functions, or lambdas:

# %%
y = apply_to_one(lambda x: x + 4)
y
# Out:
# 5

# %%
def my_print(message="my default message"):
    print(message)

# %%
my_print("hello")
my_print()
# Out:
# hello
# my default message
